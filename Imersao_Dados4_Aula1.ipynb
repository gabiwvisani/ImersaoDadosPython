# %%
#aula 1 encontrada em https://www.alura.com.br/imersao-dados-4/aula01-colab-python-pandas?utm_source=ActiveCampaign&utm_medium=email&utm_content=%5BImers%C3%A3o+Dados%5D+Aula+1+Liberada%21+%F0%9F%94%90&utm_campaign=%5BImers%C3%A3o%5D+%28Dados%29+Libera%C3%A7%C3%A3o+Aula+01&vgo_ee=l4OaDvf68w08jny2acKE1DpxdzkQNl9LgdxZ9pnzLRY%3D

import pandas as pd
url ="https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)

# %%
dados["Bairro"][6522]

# %%
dados.info()

# %%
dados.Metragem.mean()

# %%
sum(dados["Bairro"] == "Vila Mariana")

# %%
tem_imoveis_vm =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vm
dados[tem_imoveis_vm]

# %%
imoveis_vm =dados[tem_imoveis_vm]
imoveis_vm["Metragem"].mean()

# %%
dados["Bairro"].value_counts()

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %%
#Desafio: 
#1.(Paulo) Média metragem por bairro.
#2. (thiago) Duas formas de selecionar os dados por bairro (consultar documentação do pandas)
#3. (thiago) Explorar alguns gráficos na documentação e aplicar nas demais colunas do data frame. Tentar adicionar alguma conclusão também.
#4. (Vivi) Descobrir mediana, minimo e máximo, comparar esses 3 e a média e tirar conclusões sobre a metragem.
#5. (Vivi) Descobrir quais são os bairros que não tem o nome de rua.

# %%
# Desafio 1
media_metragem=dados.loc[:,["Bairro","Metragem"]].groupby("Bairro")
media_metragem.mean()
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988
# ...                       ...
# Vila Água Funda    152.200000
# Água Branca        191.000000
# Água Fria          165.416667
# Água Funda         139.000000
# Água Rasa          340.250000
#
# [701 rows x 1 columns]

# %%
# Desafio 2
vm =['Vila Mariana']
dados.Bairro.isin(vm)
tem_imoveis_vm = dados[dados.Bairro.isin(vm)]
tem_imoveis_vm.head()
# Out:
#                               Rua        Bairro     Cidade  Metragem  Quartos  \
# 100              Rua Pero Correia  Vila Mariana  São Paulo       250        3
# 120  Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250        3
# 155    Rua Professor João Marinho  Vila Mariana  São Paulo       170        3
# 160                           NaN  Vila Mariana  São Paulo       228        4
# 334        Rua Pero Correia, 892   Vila Mariana  São Paulo       350        6
#
#      Banheiros  Vagas         Valor
# 100          3      1  R$ 1.350.000
# 120          5      2  R$ 2.450.000
# 155          4      2  R$ 1.490.000
# 160          5      3  R$ 2.200.000
# 334          4     10  R$ 1.700.000

# %%
# Desafio 2
tem_imoveis_vm2 =dados[(dados.loc[:,"Bairro"] == "Vila Mariana")]
tem_imoveis_vm2.head()
# Out:
#                               Rua        Bairro     Cidade  Metragem  Quartos  \
# 100              Rua Pero Correia  Vila Mariana  São Paulo       250        3
# 120  Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250        3
# 155    Rua Professor João Marinho  Vila Mariana  São Paulo       170        3
# 160                           NaN  Vila Mariana  São Paulo       228        4
# 334        Rua Pero Correia, 892   Vila Mariana  São Paulo       350        6
#
#      Banheiros  Vagas         Valor
# 100          3      1  R$ 1.350.000
# 120          5      2  R$ 2.450.000
# 155          4      2  R$ 1.490.000
# 160          5      3  R$ 2.200.000
# 334          4     10  R$ 1.700.000

# %%
#Desafio 3
dados.plot(x='Bairro', y='Vagas', kind='bar')
# Out:
# Error in callback <function flush_figures at 0x7fbd7bb943b0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %%
#Desafio4
vm =['Vila Mariana']
dados.Bairro.isin(vm)
tem_imoveis_vm = dados[dados.Bairro.isin(vm)]
tem_imoveis_vm.Metragem.min()
# Out:
# 60

# %%
#Desafio4
tem_imoveis_vm.Metragem.max()
# Out:
# 650

# %%
#Desafio4
tem_imoveis_vm.Metragem.median()
# Out:
# 235.5

# %%
#Desafio4
tem_imoveis_vm.Metragem.mean()
#Conclusões preliminares apenas levando em consideração mínimo, máximo, mediana e média. 
#A mediana está próxima a média o que apontaria para uma distribuição com menos pontos outliers ou pontos outliers que se equilibram. 
#Vendo no entanto a mínima e máxima da para perceber que o range de resultados de metragem é grande.
# Out:
# 233.6195652173913

# %%
#Desafio5
tem_imoveis_isnull = dados[dados.Rua.isnull()]
tem_imoveis_isnull["Bairro"].value_counts()
#tem_imoveis_isnull["Bairro"].describe()
#Resposta: 394 bairros tem algum cadastro sem nome de rua, são eles:
# Out:
# Jardim Guedala                      190
# Alto de Pinheiros                   169
# Jardim Paulista                     138
# Jardim Europa                       128
# Jardim Leonor                       118
#                                    ...
# Jardim do Colégio (Zona Norte)        1
# Alto da Boa Vista                     1
# Jardim Aeroporto                      1
# Conjunto Residencial Vista Verde      1
# Jardim Santo Elias                    1
# Name: Bairro, Length: 394, dtype: int64
